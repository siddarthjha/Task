# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Reading the data

df_train = pd.read_csv("/Users/siddarthjha/Downloads/ml_data/training.csv", low_memory = False)
df_test = pd.read_csv("/Users/siddarthjha/Downloads/ml_data/public_test_features.csv", low_memory = False)
df_meta_data = pd.read_excel("/Users/siddarthjha/Downloads/ml_data/metadata-dataset.xlsx")

# %%
# The shape of Train and Test
df_train.shape, df_test.shape
# Out:
# ((36803, 228), (15774, 227))

# %%
y_train = df_train['label']

# %%
# Dropping ID column
df_train.drop(['ID', 'label'], axis = 1, inplace = True)
df_test.drop(['ID'], axis = 1, inplace = True)
# calculating category & integer type columns 
cat_vars=list(df_train.select_dtypes(include=['object']).columns)
num_vars=list(df_train.select_dtypes(exclude=['object']).columns)
len(cat_vars), len(num_vars)
# Out:
# (126, 100)

# %%
# for i in df_train.columns:
#     if i in cat_vars:
#         print("Total length of cat - {0} is {1}".format(i, len(df_train[i].value_counts())))

# From this selecting the categorical features which has only 20 categories

drop_cat_vars = []
for i in cat_vars:
    if len(df_train[i].value_counts()) > 20:
        drop_cat_vars.append(i)
selected_cat_vars = list(set(cat_vars) - set(drop_cat_vars))
len(selected_cat_vars)
# Out:
# 80

# %%
# Handling the null values with 0
df_train.fillna(0, inplace = True)
df_test.fillna(0, inplace = True)

# %%
train = pd.get_dummies(data = df_train, columns = selected_cat_vars)
test = pd.get_dummies(data = df_test, columns = selected_cat_vars)

# %%
train.shape, test.shape
# Out:
# ((36803, 435), (15774, 417))

# %%
x_train, x_test = train.align(test, join='left', axis=1)
x_train.shape, x_test.shape
# Out:
# ((36803, 435), (15774, 435))

# %%
cat_vars_new=list(x_train.select_dtypes(include=['object']).columns)
# Dropping off the unnecassary categorical features
x_train.drop(cat_vars_new, inplace = True, axis = 1)
x_test.drop(cat_vars_new, inplace = True, axis = 1)
x_train.shape, x_test.shape
# Out:
# ((36803, 389), (15774, 389))

# %%
model = RandomForestClassifier(n_estimators = 500,
                            criterion = 'entropy',
                            class_weight = 'balanced',
                            min_samples_split = 1000,
                            random_state = 1,
                            n_jobs = -1)

# %%
feature_cols = ['key_Region Id',
 'key_MarketPlace Id',
 'key_country_of_origin',
 'key_discontinued_date',
 'key_fedas_id',
 'key_isbn',
 'key_manufacturer_sku',
 'key_monthly_recurring_charge',
 'key_number_of_licenses',
 'key_number_of_pages',
 'key_number_of_points',
 'key_preferred_vendor',
 'key_publisher',
 'key_recall_external_identifier',
 'key_recall_notice_expiration_date',
 'key_recall_notice_publication_date',
 'key_recall_notice_receive_date',
 'cand_Region Id',
 'cand_MarketPlace Id',
 'cand_country_of_origin',
 'cand_discontinued_date',
 'cand_esrb_descriptors',
 'cand_fedas_id',
 'cand_manufacturer_sku',
 'cand_monthly_recurring_charge',
 'cand_number_of_pages',
 'cand_number_of_points',
 'cand_preferred_vendor',
 'cand_publisher',
 'cand_recall_external_identifier',
 'cand_recall_notice_expiration_date',
 'cand_recall_notice_publication_date',
 'cand_recall_notice_receive_date',
 'cand_currency_code_USD',
 'cand_item_display_volume_uom_cubic_centimeters',
 'cand_item_display_volume_uom_cubic_meters',
 'cand_item_display_volume_uom_cups',
 'cand_item_display_volume_uom_gallons',
 'cand_item_display_volume_uom_grams',
 'cand_item_display_volume_uom_ounces',
 'cand_item_display_volume_uom_pints',
 'cand_item_display_volume_uom_quarts',
 'key_currency_code_USD',
 'cand_video_game_region_description_0',
 'cand_video_game_region_description_ntsc_uc',
 'cand_video_game_region_description_region_free',
 'cand_is_discontinued_N',
 'cand_is_manufacture_on_demand_N',
 'key_language_code_en_US',
 'key_inner_package_type_0',
 'key_inner_package_type_41_deluxe_bangle_hoops',
 'cand_wireless_provider_code_cingular',
 'cand_wireless_provider_code_sprintpcs',
 'cand_wireless_provider_code_t_mobile',
 'cand_wireless_provider_code_virgin_mobile',
 'key_esrb_age_rating_everyone_10_plus',
 'key_mfg_series_number_GENESIS 330',
 'key_mfg_series_number_PIXMA',
 'key_mfg_series_number_SoundSport',
 'cand_classification_description_0',
 'cand_classification_description_Collection Parent',
 'cand_customer_return_method_free_return',
 'cand_customer_return_method_mail',
 'cand_customer_return_method_unknown',
 'cand_classification_code_0',
 'cand_classification_code_collection_parent',
 'cand_program_member_Advantage',
 'cand_program_member_Caterpillar',
 'cand_program_member_Create With Amazon',
 'cand_program_member_Invite Model',
 'cand_is_super_saver_shipping_excl_Y',
 'cand_is_advantage_N',
 'cand_is_advantage_Y',
 'key_is_advantage_N',
 'cand_item_display_weight_uom_milligrams',
 'cand_release_date_embargo_level_low',
 'cand_release_date_embargo_level_none',
 'cand_release_date_embargo_level_strict',
 'cand_inner_package_type_38_deluxe_med',
 'cand_inner_package_type_39_deluxe_bracelet',
 'cand_inner_package_type_41_deluxe_bangle_hoops',
 'cand_inner_package_type_42_classic_sml',
 'cand_inner_package_type_43_classic_med',
 'cand_inner_package_type_44_oversized_med',
 'key_has_online_play_N',
 'cand_item_display_length_uom_feet',
 'key_is_discontinued_N',
 'key_is_super_saver_shipping_excl_Y',
 'cand_language_code_en_US',
 'key_is_manufacture_on_demand_N',
 'cand_wireless_provider_Sprint',
 'cand_wireless_provider_T-Mobile',
 'cand_wireless_provider_Virgin Mobile',
 'cand_is_phone_upgradeable_N',
 'cand_has_online_play_N',
 'cand_has_online_play_Y',
 'cand_program_member_code_advantage',
 'cand_program_member_code_caterpillar',
 'cand_program_member_code_create_with_amazon',
 'cand_program_member_code_invite_model',
 'cand_esrb_age_rating_0',
 'cand_esrb_age_rating_everyone_10_plus',
 'cand_esrb_age_rating_kids_to_adults',
 'cand_esrb_age_rating_mature',
 'cand_esrb_age_rating_rating_pending',
 'cand_esrb_age_rating_teen',
 'cand_fma_override_0',
 'cand_fma_override_bypass_buybox_overpriced_filter',
 'cand_cpsia_cautionary_statement_choking_hazard_contains_a_marble',
 'cand_cpsia_cautionary_statement_choking_hazard_contains_small_ball',
 'cand_cpsia_cautionary_statement_choking_hazard_is_a_marble',
 'cand_cpsia_cautionary_statement_choking_hazard_is_a_small_ball',
 'cand_cpsia_cautionary_statement_contains_small_magnets',
 'key_ordering_channel_jewelry_ordering_channel',
 'key_ordering_channel_software_ordering_channel']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train1, y_test = train_test_split(x_train[feature_cols], y_train, test_size = 0.30)

# %%
# %%time
model.fit(X_train, y_train1)
# Out:
# CPU times: user 26 s, sys: 195 ms, total: 26.2 s
# Wall time: 4.59 s
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        min_samples_split=1000, n_estimators=500, n_jobs=-1,
#                        random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
metrics.confusion_matrix(y_test, y_pred)
# Out:
# array([[3659, 1859],
#        [2327, 3196]])

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
print("Recall OF THE MODEL: ", metrics.recall_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.6208676750294357
# Recall OF THE MODEL:  0.5786710121310882

# %%
feature_columns = x_train.columns

# %%
importances = list(100*model.feature_importances_)# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_columns, importances)]# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: key_variation_theme_id Importance: 4.72
# Variable: cand_fma_qualified_price_max Importance: 4.44
# Variable: key_product_type_id  Importance: 4.08
# Variable: cand_pkg_width       Importance: 3.66
# Variable: key_fma_qualified_price_max Importance: 3.29
# Variable: cand_pkg_weight      Importance: 3.2
# Variable: key_Product Group Code Importance: 3.08
# Variable: key_pkg_length       Importance: 2.97
# Variable: key_pkg_weight       Importance: 2.91
# Variable: cand_pkg_height      Importance: 2.89
# Variable: cand_version         Importance: 2.82
# Variable: cand_product_type_id Importance: 2.69
# Variable: key_pkg_width        Importance: 2.64
# Variable: key_pkg_height       Importance: 2.52
# Variable: cand_Product Group Code Importance: 2.43
# Variable: cand_pkg_length      Importance: 2.07
# Variable: cand_variation_theme_id Importance: 1.87
# Variable: key_version          Importance: 1.77
# Variable: key_upc              Importance: 1.44
# Variable: key_item_weight      Importance: 1.32
# Variable: key_item_length      Importance: 1.27
# Variable: key_item_width       Importance: 1.24
# Variable: cand_case_pack_quantity Importance: 1.19
# Variable: cand_item_weight     Importance: 1.1
# Variable: cand_upc             Importance: 1.1
# Variable: key_item_height      Importance: 1.08
# Variable: cand_Is Sortable_N   Importance: 1.02
# Variable: cand_Is Sortable_Y   Importance: 1.01
# Variable: cand_item_width      Importance: 0.96
# Variable: cand_customer_return_policy_0 Importance: 0.95
# Variable: cand_item_height     Importance: 0.94
# Variable: cand_number_of_items Importance: 0.93
# Variable: key_ordering_channel_watch_ordering_channel Importance: 0.93
# Variable: key_ean              Importance: 0.89
# Variable: key_item_display_weight Importance: 0.84
# Variable: key_excluded_direct_browse_node_id Importance: 0.79
# Variable: cand_item_length     Importance: 0.79
# Variable: cand_excluded_direct_browse_node_id Importance: 0.74
# Variable: key_Is Sortable_Y    Importance: 0.74
# Variable: cand_ean             Importance: 0.7
# Variable: key_Is Sortable_N    Importance: 0.67
# Variable: cand_item_display_weight Importance: 0.62
# Variable: key_case_pack_quantity Importance: 0.52
# Variable: key_number_of_items  Importance: 0.49
# Variable: cand_classification_code_variation_parent Importance: 0.47
# Variable: key_item_display_width Importance: 0.46
# Variable: key_item_display_height Importance: 0.44
# Variable: key_item_package_quantity Importance: 0.42
# Variable: cand_customer_return_policy_standard Importance: 0.4
# Variable: cand_is_adult_product_N Importance: 0.4
# Variable: key_item_display_length Importance: 0.38
# Variable: cand_classification_description_Variation Parent Importance: 0.38
# Variable: key_unit_count       Importance: 0.37
# Variable: cand_unit_count      Importance: 0.37
# Variable: key_release_date_embargo_level_high Importance: 0.36
# Variable: cand_is_adult_product_0 Importance: 0.33
# Variable: cand_customer_return_policy_non_returnable Importance: 0.32
# Variable: cand_item_classification_id Importance: 0.3
# Variable: cand_item_package_quantity Importance: 0.3
# Variable: key_is_adult_product_0 Importance: 0.3
# Variable: key_ordering_channel_automotive_ordering_channel Importance: 0.3
# Variable: key_ordering_channel_0 Importance: 0.29
# Variable: key_ordering_channel_home_improvement_ordering_channel Importance: 0.29
# Variable: cand_item_display_height Importance: 0.28
# Variable: key_is_adult_product_N Importance: 0.26
# Variable: cand_item_display_length Importance: 0.25
# Variable: cand_program_member_0 Importance: 0.25
# Variable: cand_program_member_code_0 Importance: 0.25
# Variable: cand_classification_description_Base Product Importance: 0.25
# Variable: key_customer_return_policy_standard Importance: 0.24
# Variable: cand_item_display_width Importance: 0.23
# Variable: key_target_gender_0  Importance: 0.23
# Variable: cand_program_member_code_bulk_fulfillment Importance: 0.22
# Variable: cand_has_recommended_browse_nodes_N Importance: 0.22
# Variable: cand_has_recommended_browse_nodes_Y Importance: 0.22
# Variable: cand_pkg_weight_uom_pounds Importance: 0.22
# Variable: key_publication_year Importance: 0.21
# Variable: cand_program_member_Bulk Fulfillment Importance: 0.21
# Variable: cand_item_display_weight_uom_pounds Importance: 0.21
# Variable: key_publication_day  Importance: 0.2
# Variable: key_publication_month Importance: 0.2
# Variable: cand_pkg_dimensional_uom_0 Importance: 0.19
# Variable: cand_pkg_weight_uom_0 Importance: 0.18
# Variable: key_item_display_volume Importance: 0.17
# Variable: key_item_display_weight_uom_grams Importance: 0.17
# Variable: cand_classification_code_base_product Importance: 0.17
# Variable: cand_pkg_dimensional_uom_inches Importance: 0.17
# Variable: key_is_conveyable_N  Importance: 0.17
# Variable: key_is_conveyable_Y  Importance: 0.16
# Variable: cand_is_conveyable_Y Importance: 0.16
# Variable: cand_publication_month Importance: 0.15
# Variable: cand_is_deleted_N    Importance: 0.15
# Variable: cand_is_deleted_Y    Importance: 0.15
# Variable: key_fma_override_bypass_buybox_overpriced_filter Importance: 0.15
# Variable: key_ordering_channel_baby_product_ordering_channel Importance: 0.15
# Variable: cand_is_conveyable_N Importance: 0.15
# Variable: key_pkg_weight_uom_0 Importance: 0.15
# Variable: key_esrb_age_rating_teen Importance: 0.14
# Variable: key_max_weight_recommendation Importance: 0.13
# Variable: key_ordering_channel_ce_ordering_channel Importance: 0.13
# Variable: key_customer_return_policy_0 Importance: 0.13
# Variable: cand_publication_year Importance: 0.12
# Variable: key_fma_override_0   Importance: 0.12
# Variable: cand_target_gender_male Importance: 0.12
# Variable: key_target_gender_male Importance: 0.12
# Variable: key_has_platform_Y   Importance: 0.12
# Variable: key_ordering_channel_office_product_ordering_channel Importance: 0.12
# Variable: key_ordering_channel_toy_ordering_channel Importance: 0.12
# Variable: key_is_super_saver_shipping_excl_0 Importance: 0.12
# Variable: key_pkg_weight_uom_pounds Importance: 0.12
# Variable: cand_item_display_volume Importance: 0.11
# Variable: cand_publication_day Importance: 0.11
# Variable: key_item_display_weight_uom_ounces Importance: 0.11
# Variable: key_target_gender_unisex Importance: 0.11
# Variable: key_has_platform_N   Importance: 0.11
# Variable: cand_item_display_weight_uom_0 Importance: 0.11
# Variable: cand_has_upc_N       Importance: 0.11
# Variable: key_item_display_diameter Importance: 0.1
# Variable: key_item_display_weight_uom_pounds Importance: 0.1
# Variable: cand_target_gender_0 Importance: 0.1
# Variable: key_delivery_option_direct_ship Importance: 0.1
# Variable: key_ordering_channel_kitchen_ordering_channel Importance: 0.1
# Variable: cand_has_upc_Y       Importance: 0.1
# Variable: key_pkg_dimensional_uom_inches Importance: 0.1
# Variable: cand_delivery_option_0 Importance: 0.09
# Variable: key_is_adult_product_Y Importance: 0.09
# Variable: key_release_date_embargo_level_0 Importance: 0.09
# Variable: key_ordering_channel_gourmet_ordering_channel Importance: 0.09
# Variable: key_has_recommended_browse_nodes_Y Importance: 0.08
# Variable: key_target_gender_female Importance: 0.08
# Variable: key_ordering_channel_sporting_goods_ordering_channel Importance: 0.08
# Variable: key_customer_return_policy_non_returnable Importance: 0.08
# Variable: key_esrb_age_rating_0 Importance: 0.08
# Variable: key_is_deleted_N     Importance: 0.08
# Variable: key_is_deleted_Y     Importance: 0.08
# Variable: key_is_super_saver_shipping_excl_N Importance: 0.08
# Variable: cand_item_display_diameter Importance: 0.07
# Variable: cand_delivery_option_in_store Importance: 0.07
# Variable: key_has_recommended_browse_nodes_N Importance: 0.07
# Variable: key_program_member_0 Importance: 0.07
# Variable: cand_cpsia_cautionary_statement_0 Importance: 0.07
# Variable: key_item_display_volume_uom_0 Importance: 0.06
# Variable: key_item_display_weight_uom_kilograms Importance: 0.06
# Variable: cand_item_display_length_uom_0 Importance: 0.06
# Variable: key_pkg_dimensional_uom_0 Importance: 0.06
# Variable: cand_has_platform_Y  Importance: 0.06
# Variable: cand_max_weight_recommendation Importance: 0.05
# Variable: key_item_display_volume_uom_milliliters Importance: 0.05
# Variable: key_customer_return_method_0 Importance: 0.05
# Variable: key_cpsia_cautionary_statement_0 Importance: 0.05
# Variable: key_has_upc_Y        Importance: 0.05
# Variable: key_item_display_length_uom_0 Importance: 0.05
# Variable: key_item_display_length_uom_millimeters Importance: 0.05
# Variable: key_has_ean_N        Importance: 0.05
# Variable: key_has_ean_Y        Importance: 0.05
# Variable: key_is_certified_organic_0 Importance: 0.05
# Variable: key_ordering_channel_pc_ordering_channel Importance: 0.05
# Variable: key_ordering_channel_universal_catalog_ordering_channel Importance: 0.05
# Variable: cand_item_display_weight_uom_kilograms Importance: 0.05
# Variable: cand_has_ean_N       Importance: 0.05
# Variable: cand_has_ean_Y       Importance: 0.05
# Variable: key_program_member_Bulk Fulfillment Importance: 0.05
# Variable: key_wireless_provider_0 Importance: 0.05
# Variable: cand_cpsia_cautionary_statement_choking_hazard_small_parts Importance: 0.05
# Variable: cand_cpsia_cautionary_statement_no_warning_applicable Importance: 0.05
# Variable: key_customer_return_method_no_return Importance: 0.04
# Variable: cand_item_display_length_uom_centimeters Importance: 0.04
# Variable: key_cpsia_cautionary_statement_no_warning_applicable Importance: 0.04
# Variable: cand_wireless_provider_0 Importance: 0.04
# Variable: cand_item_display_volume_uom_milliliters Importance: 0.04
# Variable: key_item_display_length_uom_centimeters Importance: 0.04
# Variable: key_item_display_length_uom_inches Importance: 0.04
# Variable: key_is_certified_organic_N Importance: 0.04
# Variable: key_ordering_channel_biss_ordering_channel Importance: 0.04
# Variable: key_ordering_channel_wireless_ordering_channel Importance: 0.04
# Variable: cand_item_display_weight_uom_grams Importance: 0.04
# Variable: key_program_member_Pantry Importance: 0.04
# Variable: cand_wireless_provider_code_0 Importance: 0.04
# Variable: cand_wireless_provider_code_verizon Importance: 0.04
# Variable: key_mfg_series_number_0 Importance: 0.04
# Variable: cand_has_platform_N  Importance: 0.04
# Variable: key_program_member_code_0 Importance: 0.04
# Variable: key_program_member_code_bulk_fulfillment Importance: 0.04
# Variable: key_program_member_code_pantry Importance: 0.04
# Variable: key_min_weight_recommendation Importance: 0.03
# Variable: cand_min_weight_recommendation Importance: 0.03
# Variable: key_is_phone_upgradeable_0 Importance: 0.03
# Variable: key_is_phone_upgradeable_Y Importance: 0.03
# Variable: cand_is_phone_upgradeable_Y Importance: 0.03
# Variable: cand_delivery_option_direct_ship Importance: 0.03
# Variable: cand_customer_return_method_0 Importance: 0.03
# Variable: key_item_display_weight_uom_0 Importance: 0.03
# Variable: cand_target_gender_female Importance: 0.03
# Variable: cand_item_display_length_uom_inches Importance: 0.03
# Variable: key_cpsia_cautionary_statement_choking_hazard_small_parts Importance: 0.03
# Variable: cand_wireless_provider_Verizon Importance: 0.03
# Variable: cand_item_display_volume_uom_0 Importance: 0.03
# Variable: key_has_upc_N        Importance: 0.03
# Variable: key_wireless_provider_code_att Importance: 0.03
# Variable: key_wireless_provider_code_verizon Importance: 0.03
# Variable: key_delivery_option_0 Importance: 0.03
# Variable: key_delivery_option_in_store Importance: 0.03
# Variable: key_ordering_channel_lawn_and_garden_ordering_channel Importance: 0.03
# Variable: key_ordering_channel_musical_instruments_ordering_channel Importance: 0.03
# Variable: key_ordering_channel_unorderable_ordering_channel Importance: 0.03
# Variable: cand_classification_description_Product Bundle Importance: 0.03
# Variable: cand_release_date_embargo_level_0 Importance: 0.03
# Variable: cand_release_date_embargo_level_high Importance: 0.03
# Variable: key_program_member_Boost Importance: 0.03
# Variable: key_program_member_code_boost Importance: 0.03
# Variable: key_video_game_region Importance: 0.02
# Variable: cand_is_phone_upgradeable_0 Importance: 0.02
# Variable: cand_customer_return_method_no_return Importance: 0.02
# Variable: key_item_display_volume_uom_fluid_ounces Importance: 0.02
# Variable: cand_target_gender_unisex Importance: 0.02
# Variable: cand_is_super_saver_shipping_excl_0 Importance: 0.02
# Variable: cand_is_super_saver_shipping_excl_N Importance: 0.02
# Variable: cand_item_display_length_uom_millimeters Importance: 0.02
# Variable: key_wireless_provider_code_0 Importance: 0.02
# Variable: cand_is_certified_organic_0 Importance: 0.02
# Variable: cand_classification_code_product_bundle Importance: 0.02
# Variable: key_release_date_embargo_level_none Importance: 0.02
# Variable: key_ordering_channel_apparel_ordering_channel Importance: 0.02
# Variable: cand_item_display_weight_uom_ounces Importance: 0.02
# Variable: key_classification_code_product_bundle Importance: 0.02
# Variable: key_classification_description_Product Bundle Importance: 0.02
# Variable: key_wireless_provider_T-Mobile Importance: 0.02
# Variable: key_wireless_provider_Verizon Importance: 0.02
# Variable: key_video_game_region_description_region_free Importance: 0.02
# Variable: cand_is_adult_product_Y Importance: 0.02
# Variable: cand_cpsia_cautionary_statement_choking_hazard_balloon Importance: 0.02
# Variable: key_fedas_id         Importance: 0.01
# Variable: key_isbn             Importance: 0.01
# Variable: key_item_classification_id Importance: 0.01
# Variable: cand_number_of_licenses Importance: 0.01
# Variable: key_recall_description_0 Importance: 0.01
# Variable: key_recall_description_Product Safety Investigation - fire incident Importance: 0.01
# Variable: cand_program_member_Boost Importance: 0.01
# Variable: cand_program_member_Pantry Importance: 0.01
# Variable: cand_program_member_code_boost Importance: 0.01
# Variable: cand_program_member_code_pantry Importance: 0.01
# Variable: key_customer_return_method_free_return Importance: 0.01
# Variable: key_customer_return_method_mail Importance: 0.01
# Variable: cand_item_display_length_uom_meters Importance: 0.01
# Variable: key_cpsia_cautionary_statement_choking_hazard_balloon Importance: 0.01
# Variable: cand_item_display_volume_uom_fluid_ounces Importance: 0.01
# Variable: cand_item_display_volume_uom_liters Importance: 0.01
# Variable: key_wireless_provider_code_sprintpcs Importance: 0.01
# Variable: key_wireless_provider_code_t_mobile Importance: 0.01
# Variable: cand_is_certified_organic_N Importance: 0.01
# Variable: key_item_display_length_uom_feet Importance: 0.01
# Variable: cand_esrb_age_rating_0 Importance: 0.01
# Variable: key_release_date_embargo_level_strict Importance: 0.01
# Variable: key_ordering_channel_software_ordering_channel Importance: 0.01
# Variable: key_esrb_age_rating_everyone Importance: 0.01
# Variable: key_classification_code_base_product Importance: 0.01
# Variable: key_is_super_saver_shipping_excl_Y Importance: 0.01
# Variable: cand_release_date_embargo_level_none Importance: 0.01
# Variable: cand_wireless_provider_code_att Importance: 0.01
# Variable: cand_wireless_provider_code_sprintpcs Importance: 0.01
# Variable: key_mfg_series_number_312-1250 Importance: 0.01
# Variable: key_mfg_series_number_????HGUC?? Importance: 0.01
# Variable: key_mfg_series_number_Brother TN2310 Importance: 0.01
# Variable: key_mfg_series_number_EOS REBEL Importance: 0.01
# Variable: key_mfg_series_number_HP 410A Importance: 0.01
# Variable: key_mfg_series_number_SoundSport Importance: 0.01
# Variable: key_wireless_provider_AT&T Importance: 0.01
# Variable: key_video_game_region_description_0 Importance: 0.01
# Variable: key_inner_package_type_41_deluxe_bangle_hoops Importance: 0.01
# Variable: key_Region Id        Importance: 0.0
# Variable: key_MarketPlace Id   Importance: 0.0
# Variable: key_country_of_origin Importance: 0.0
# Variable: key_discontinued_date Importance: 0.0
# Variable: key_manufacturer_sku Importance: 0.0
# Variable: key_monthly_recurring_charge Importance: 0.0
# Variable: key_number_of_licenses Importance: 0.0
# Variable: key_number_of_pages  Importance: 0.0
# Variable: key_number_of_points Importance: 0.0
# Variable: key_preferred_vendor Importance: 0.0
# Variable: key_publisher        Importance: 0.0
# Variable: key_recall_external_identifier Importance: 0.0
# Variable: key_recall_notice_expiration_date Importance: 0.0
# Variable: key_recall_notice_publication_date Importance: 0.0
# Variable: key_recall_notice_receive_date Importance: 0.0
# Variable: cand_Region Id       Importance: 0.0
# Variable: cand_MarketPlace Id  Importance: 0.0
# Variable: cand_country_of_origin Importance: 0.0
# Variable: cand_discontinued_date Importance: 0.0
# Variable: cand_esrb_descriptors Importance: 0.0
# Variable: cand_fedas_id        Importance: 0.0
# Variable: cand_manufacturer_sku Importance: 0.0
# Variable: cand_monthly_recurring_charge Importance: 0.0
# Variable: cand_number_of_pages Importance: 0.0
# Variable: cand_number_of_points Importance: 0.0
# Variable: cand_preferred_vendor Importance: 0.0
# Variable: cand_publisher       Importance: 0.0
# Variable: cand_recall_external_identifier Importance: 0.0
# Variable: cand_recall_notice_expiration_date Importance: 0.0
# Variable: cand_recall_notice_publication_date Importance: 0.0
# Variable: cand_recall_notice_receive_date Importance: 0.0
# Variable: cand_video_game_region Importance: 0.0
# Variable: cand_is_phone_upgradeable_N Importance: 0.0
# Variable: cand_language_code_en_US Importance: 0.0
# Variable: cand_customer_return_method_free_return Importance: 0.0
# Variable: cand_customer_return_method_mail Importance: 0.0
# Variable: cand_customer_return_method_unknown Importance: 0.0
# Variable: key_item_display_volume_uom_liters Importance: 0.0
# Variable: key_esrb_descriptors_0 Importance: 0.0
# Variable: key_esrb_descriptors_Teen Importance: 0.0
# Variable: cand_is_manufacture_on_demand_N Importance: 0.0
# Variable: key_recall_description_Product Safety Investigation Importance: 0.0
# Variable: cand_program_member_Advantage Importance: 0.0
# Variable: cand_program_member_Caterpillar Importance: 0.0
# Variable: cand_program_member_Create With Amazon Importance: 0.0
# Variable: cand_program_member_Invite Model Importance: 0.0
# Variable: cand_program_member_code_advantage Importance: 0.0
# Variable: cand_program_member_code_caterpillar Importance: 0.0
# Variable: cand_program_member_code_create_with_amazon Importance: 0.0
# Variable: cand_program_member_code_invite_model Importance: 0.0
# Variable: cand_is_advantage_N  Importance: 0.0
# Variable: cand_is_advantage_Y  Importance: 0.0
# Variable: cand_is_super_saver_shipping_excl_Y Importance: 0.0
# Variable: cand_item_display_length_uom_feet Importance: 0.0
# Variable: cand_has_online_play_N Importance: 0.0
# Variable: cand_has_online_play_Y Importance: 0.0
# Variable: cand_wireless_provider_AT&T Importance: 0.0
# Variable: cand_wireless_provider_Sprint Importance: 0.0
# Variable: cand_wireless_provider_T-Mobile Importance: 0.0
# Variable: cand_wireless_provider_Virgin Mobile Importance: 0.0
# Variable: cand_item_display_volume_uom_cubic_centimeters Importance: 0.0
# Variable: cand_item_display_volume_uom_cubic_meters Importance: 0.0
# Variable: cand_item_display_volume_uom_cups Importance: 0.0
# Variable: cand_item_display_volume_uom_gallons Importance: 0.0
# Variable: cand_item_display_volume_uom_grams Importance: 0.0
# Variable: cand_item_display_volume_uom_ounces Importance: 0.0
# Variable: cand_item_display_volume_uom_pints Importance: 0.0
# Variable: cand_item_display_volume_uom_quarts Importance: 0.0
# Variable: key_currency_code_USD Importance: 0.0
# Variable: key_has_online_play_N Importance: 0.0
# Variable: cand_classification_code_0 Importance: 0.0
# Variable: cand_classification_code_collection_parent Importance: 0.0
# Variable: key_item_display_length_uom_meters Importance: 0.0
# Variable: cand_esrb_age_rating_everyone Importance: 0.0
# Variable: cand_esrb_age_rating_everyone_10_plus Importance: 0.0
# Variable: cand_esrb_age_rating_kids_to_adults Importance: 0.0
# Variable: cand_esrb_age_rating_mature Importance: 0.0
# Variable: cand_esrb_age_rating_rating_pending Importance: 0.0
# Variable: cand_esrb_age_rating_teen Importance: 0.0
# Variable: key_language_code_en_US Importance: 0.0
# Variable: key_ordering_channel_jewelry_ordering_channel Importance: 0.0
# Variable: cand_inner_package_type_0 Importance: 0.0
# Variable: cand_inner_package_type_38_deluxe_med Importance: 0.0
# Variable: cand_inner_package_type_39_deluxe_bracelet Importance: 0.0
# Variable: cand_inner_package_type_41_deluxe_bangle_hoops Importance: 0.0
# Variable: cand_inner_package_type_42_classic_sml Importance: 0.0
# Variable: cand_inner_package_type_43_classic_med Importance: 0.0
# Variable: cand_inner_package_type_44_oversized_med Importance: 0.0
# Variable: key_esrb_age_rating_everyone_10_plus Importance: 0.0
# Variable: cand_classification_description_0 Importance: 0.0
# Variable: cand_classification_description_Collection Parent Importance: 0.0
# Variable: key_is_discontinued_N Importance: 0.0
# Variable: cand_item_display_weight_uom_milligrams Importance: 0.0
# Variable: cand_release_date_embargo_level_low Importance: 0.0
# Variable: cand_release_date_embargo_level_strict Importance: 0.0
# Variable: cand_is_discontinued_N Importance: 0.0
# Variable: key_is_manufacture_on_demand_N Importance: 0.0
# Variable: cand_wireless_provider_code_cingular Importance: 0.0
# Variable: cand_wireless_provider_code_t_mobile Importance: 0.0
# Variable: cand_wireless_provider_code_virgin_mobile Importance: 0.0
# Variable: key_mfg_series_number_3260 Importance: 0.0
# Variable: key_mfg_series_number_GENESIS 330 Importance: 0.0
# Variable: key_mfg_series_number_Good Grips POP Importance: 0.0
# Variable: key_mfg_series_number_PIXMA Importance: 0.0
# Variable: key_mfg_series_number_core&#x6838;&#x5FC3; Importance: 0.0
# Variable: key_classification_description_Base Product Importance: 0.0
# Variable: key_wireless_provider_Sprint Importance: 0.0
# Variable: key_is_advantage_N   Importance: 0.0
# Variable: cand_video_game_region_description_0 Importance: 0.0
# Variable: cand_video_game_region_description_ntsc_uc Importance: 0.0
# Variable: cand_video_game_region_description_region_free Importance: 0.0
# Variable: cand_cpsia_cautionary_statement_choking_hazard_contains_a_marble Importance: 0.0
# Variable: cand_cpsia_cautionary_statement_choking_hazard_contains_small_ball Importance: 0.0
# Variable: cand_cpsia_cautionary_statement_choking_hazard_is_a_marble Importance: 0.0
# Variable: cand_cpsia_cautionary_statement_choking_hazard_is_a_small_ball Importance: 0.0
# Variable: cand_cpsia_cautionary_statement_contains_small_magnets Importance: 0.0
# Variable: cand_currency_code_USD Importance: 0.0
# Variable: key_inner_package_type_0 Importance: 0.0
# Variable: cand_fma_override_0  Importance: 0.0
# Variable: cand_fma_override_bypass_buybox_overpriced_filter Importance: 0.0

# %%
feature_cols = []
for p in feature_importances:
    if p[1] > 0.09:
        feature_cols.append(p[0])
feature_cols
# Out:
# ['key_variation_theme_id',
#  'cand_fma_qualified_price_max',
#  'key_product_type_id',
#  'cand_pkg_width',
#  'key_fma_qualified_price_max',
#  'cand_pkg_weight',
#  'key_Product Group Code',
#  'key_pkg_length',
#  'key_pkg_weight',
#  'cand_pkg_height',
#  'cand_version',
#  'cand_product_type_id',
#  'key_pkg_width',
#  'key_pkg_height',
#  'cand_Product Group Code',
#  'cand_pkg_length',
#  'cand_variation_theme_id',
#  'key_version',
#  'key_upc',
#  'key_item_weight',
#  'key_item_length',
#  'key_item_width',
#  'cand_case_pack_quantity',
#  'cand_item_weight',
#  'cand_upc',
#  'key_item_height',
#  'cand_Is Sortable_N',
#  'cand_Is Sortable_Y',
#  'cand_item_width',
#  'cand_customer_return_policy_0',
#  'cand_item_height',
#  'cand_number_of_items',
#  'key_ordering_channel_watch_ordering_channel',
#  'key_ean',
#  'key_item_display_weight',
#  'key_excluded_direct_browse_node_id',
#  'cand_item_length',
#  'cand_excluded_direct_browse_node_id',
#  'key_Is Sortable_Y',
#  'cand_ean',
#  'key_Is Sortable_N',
#  'cand_item_display_weight',
#  'key_case_pack_quantity',
#  'key_number_of_items',
#  'cand_classification_code_variation_parent',
#  'key_item_display_width',
#  'key_item_display_height',
#  'key_item_package_quantity',
#  'cand_customer_return_policy_standard',
#  'cand_is_adult_product_N',
#  'key_item_display_length',
#  'cand_classification_description_Variation Parent',
#  'key_unit_count',
#  'cand_unit_count',
#  'key_release_date_embargo_level_high',
#  'cand_is_adult_product_0',
#  'cand_customer_return_policy_non_returnable',
#  'cand_item_classification_id',
#  'cand_item_package_quantity',
#  'key_is_adult_product_0',
#  'key_ordering_channel_automotive_ordering_channel',
#  'key_ordering_channel_0',
#  'key_ordering_channel_home_improvement_ordering_channel',
#  'cand_item_display_height',
#  'key_is_adult_product_N',
#  'cand_item_display_length',
#  'cand_program_member_0',
#  'cand_program_member_code_0',
#  'cand_classification_description_Base Product',
#  'key_customer_return_policy_standard',
#  'cand_item_display_width',
#  'key_target_gender_0',
#  'cand_program_member_code_bulk_fulfillment',
#  'cand_has_recommended_browse_nodes_N',
#  'cand_has_recommended_browse_nodes_Y',
#  'cand_pkg_weight_uom_pounds',
#  'key_publication_year',
#  'cand_program_member_Bulk Fulfillment',
#  'cand_item_display_weight_uom_pounds',
#  'key_publication_day',
#  'key_publication_month',
#  'cand_pkg_dimensional_uom_0',
#  'cand_pkg_weight_uom_0',
#  'key_item_display_volume',
#  'key_item_display_weight_uom_grams',
#  'cand_classification_code_base_product',
#  'cand_pkg_dimensional_uom_inches',
#  'key_is_conveyable_N',
#  'key_is_conveyable_Y',
#  'cand_is_conveyable_Y',
#  'cand_publication_month',
#  'cand_is_deleted_N',
#  'cand_is_deleted_Y',
#  'key_fma_override_bypass_buybox_overpriced_filter',
#  'key_ordering_channel_baby_product_ordering_channel',
#  'cand_is_conveyable_N',
#  'key_pkg_weight_uom_0',
#  'key_esrb_age_rating_teen',
#  'key_max_weight_recommendation',
#  'key_ordering_channel_ce_ordering_channel',
#  'key_customer_return_policy_0',
#  'cand_publication_year',
#  'key_fma_override_0',
#  'cand_target_gender_male',
#  'key_target_gender_male',
#  'key_has_platform_Y',
#  'key_ordering_channel_office_product_ordering_channel',
#  'key_ordering_channel_toy_ordering_channel',
#  'key_is_super_saver_shipping_excl_0',
#  'key_pkg_weight_uom_pounds',
#  'cand_item_display_volume',
#  'cand_publication_day',
#  'key_item_display_weight_uom_ounces',
#  'key_target_gender_unisex',
#  'key_has_platform_N',
#  'cand_item_display_weight_uom_0',
#  'cand_has_upc_N',
#  'key_item_display_diameter',
#  'key_item_display_weight_uom_pounds',
#  'cand_target_gender_0',
#  'key_delivery_option_direct_ship',
#  'key_ordering_channel_kitchen_ordering_channel',
#  'cand_has_upc_Y',
#  'key_pkg_dimensional_uom_inches']

# %%
y_pred_proba = (model.predict_proba(X_test)[:,1] >= 0.4).astype(int)
print("Accuracy and recall : {0}, {1}".format(metrics.accuracy_score(y_test, y_pred_proba), metrics.recall_score(y_test, y_pred_proba)))
# Out:
# Accuracy and recall : 0.5254958789964677, 0.9808075321383306

# %%
cm_proba = metrics.confusion_matrix(y_test, y_pred_proba)
cm_proba
# Out:
# array([[ 385, 5133],
#        [ 106, 5417]])
